# %%
import pandas as pd
from scipy.io import arff
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 数据加载

# %%
def read_arrf(file):
    with open(file, encoding="utf-8") as f:
        header = []
        for line in f:
            if line.startswith("@attribute"):
                header.append(line.split(sep='\'')[1])
            elif line.startswith("@data"):
                break
        df = pd.read_csv(f, header=None)
        df.columns = header
    return df

# %%
train_df = read_arrf("../../NSL-KDD/KDDTrain+.arff")
test_df = read_arrf('../../NSL-KDD/KDDTest+.arff')

# %% [markdown]
# ### 投毒的简单案例

# %%
# 取出 index 为 8000-10000 的 2000 条数据
subset_df = train_df.loc[8000:10000,:]

# 将所有数值型属性的值修改为 5000
numeric_cols = subset_df.select_dtypes(include='number').columns
subset_df[numeric_cols] = 50000

# 将处理后的子数据集添加到原来的 dataframe 里
pos_df = pd.concat([train_df, subset_df], axis=0)
pos_df
# Out:
# /var/folders/mt/5v4kd3wd1fq7d7sc1cylkqmr0000gn/T/ipykernel_47028/2009875310.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df[numeric_cols] = 50000
# /Users/wjk/opt/miniconda3/envs/pytorch/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#        duration protocol_type   service flag  src_bytes  dst_bytes   land  \
# 0             0           tcp  ftp_data   SF        491          0      0
# 1             0           udp     other   SF        146          0      0
# 2             0           tcp   private   S0          0          0      0
# 3             0           tcp      http   SF        232       8153      0
# 4             0           tcp      http   SF        199        420      0
# ...         ...           ...       ...  ...        ...        ...    ...
# 9996      50000           tcp      http   SF      50000      50000  50000
# 9997      50000           udp  domain_u   SF      50000      50000  50000
# 9998      50000           tcp   private  REJ      50000      50000  50000
# 9999      50000          icmp     eco_i   SF      50000      50000  50000
# 10000     50000           udp     other   SF      50000      50000  50000
#
#        wrong_fragment  urgent    hot  ...  dst_host_srv_count  \
# 0                   0       0      0  ...                  25
# 1                   0       0      0  ...                   1
# 2                   0       0      0  ...                  26
# 3                   0       0      0  ...                 255
# 4                   0       0      0  ...                 255
# ...               ...     ...    ...  ...                 ...
# 9996            50000   50000  50000  ...               50000
# 9997            50000   50000  50000  ...               50000
# 9998            50000   50000  50000  ...               50000
# 9999            50000   50000  50000  ...               50000
# 10000           50000   50000  50000  ...               50000
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                        0.17                    0.03
# 1                        0.00                    0.60
# 2                        0.10                    0.05
# 3                        1.00                    0.00
# 4                        1.00                    0.00
# ...                       ...                     ...
# 9996                 50000.00                50000.00
# 9997                 50000.00                50000.00
# 9998                 50000.00                50000.00
# 9999                 50000.00                50000.00
# 10000                50000.00                50000.00
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                             0.17                         0.00
# 1                             0.88                         0.00
# 2                             0.00                         0.00
# 3                             0.03                         0.04
# 4                             0.00                         0.00
# ...                            ...                          ...
# 9996                      50000.00                     50000.00
# 9997                      50000.00                     50000.00
# 9998                      50000.00                     50000.00
# 9999                      50000.00                     50000.00
# 10000                     50000.00                     50000.00
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      0.00                      0.00                  0.05
# 1                      0.00                      0.00                  0.00
# 2                      1.00                      1.00                  0.00
# 3                      0.03                      0.01                  0.00
# 4                      0.00                      0.00                  0.00
# ...                     ...                       ...                   ...
# 9996               50000.00                  50000.00              50000.00
# 9997               50000.00                  50000.00              50000.00
# 9998               50000.00                  50000.00              50000.00
# 9999               50000.00                  50000.00              50000.00
# 10000              50000.00                  50000.00              50000.00
#
#        dst_host_srv_rerror_rate    class
# 0                          0.00   normal
# 1                          0.00   normal
# 2                          0.00  anomaly
# 3                          0.01   normal
# 4                          0.00   normal
# ...                         ...      ...
# 9996                   50000.00   normal
# 9997                   50000.00   normal
# 9998                   50000.00  anomaly
# 9999                   50000.00  anomaly
# 10000                  50000.00   normal
#
# [127974 rows x 42 columns]

# %%
train_df = train_df.sample(frac=1.0, random_state=42)
train_df
# Out:
#         duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 378            0           udp  domain_u    SF         36          0     0
# 32038          0           tcp      http    S0          0          0     0
# 86399          0           tcp     pop_3    S0          0          0     0
# 74412          0           tcp   private   REJ          0          0     0
# 52951          0           tcp   private  RSTR          0          0     0
# ...          ...           ...       ...   ...        ...        ...   ...
# 119879         0           tcp      echo  RSTO          0          0     0
# 103694         0           tcp    telnet    S0          0          0     0
# 860            0           tcp      http   REJ          0          0     0
# 15795          0           tcp      http    SF        309       4281     0
# 121958         0           udp  domain_u    SF         43         70     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 378                  0       0    0  ...                 171
# 32038                0       0    0  ...                  44
# 86399                0       0    0  ...                  20
# 74412                0       0    0  ...                  27
# 52951                0       0    0  ...                   1
# ...                ...     ...  ...  ...                 ...
# 119879               0       0    0  ...                   4
# 103694               0       0    0  ...                   4
# 860                  0       0    0  ...                   6
# 15795                0       0    0  ...                 255
# 121958               0       0    0  ...                 254
#
#         dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 378                       1.00                    0.00
# 32038                     0.17                    0.05
# 86399                     0.08                    0.06
# 74412                     0.11                    0.07
# 52951                     0.01                    0.64
# ...                        ...                     ...
# 119879                    0.02                    0.09
# 103694                    0.02                    0.07
# 860                       0.02                    0.07
# 15795                     1.00                    0.00
# 121958                    1.00                    0.01
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 378                            1.00                         0.01
# 32038                          0.01                         0.00
# 86399                          0.00                         0.00
# 74412                          0.00                         0.00
# 52951                          0.64                         0.00
# ...                             ...                          ...
# 119879                         0.00                         0.00
# 103694                         0.01                         0.00
# 860                            0.00                         0.00
# 15795                          0.05                         0.05
# 121958                         0.01                         0.00
#
#         dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 378                     0.00                       0.0                  0.00
# 32038                   1.00                       1.0                  0.00
# 86399                   1.00                       1.0                  0.00
# 74412                   0.00                       0.0                  1.00
# 52951                   0.04                       0.0                  0.63
# ...                      ...                       ...                   ...
# 119879                  0.00                       0.0                  1.00
# 103694                  1.00                       1.0                  0.00
# 860                     0.00                       0.0                  1.00
# 15795                   0.00                       0.0                  0.00
# 121958                  0.00                       0.0                  0.00
#
#         dst_host_srv_rerror_rate    class
# 378                          0.0   normal
# 32038                        0.0  anomaly
# 86399                        0.0  anomaly
# 74412                        1.0  anomaly
# 52951                        1.0  anomaly
# ...                          ...      ...
# 119879                       1.0  anomaly
# 103694                       0.0  anomaly
# 860                          1.0  anomaly
# 15795                        0.0   normal
# 121958                       0.0   normal
#
# [125973 rows x 42 columns]

# %%
pos_df = pos_df.sample(frac=1.0, random_state=42)
pos_df
# Out:
#         duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 35336          0           tcp   private   REJ          0          0     0
# 15594          0           tcp  ftp_data    S0          0          0     0
# 16218          0           tcp     pop_3    SF         52       1066     0
# 109730         0           tcp     other   REJ          0          0     0
# 93900          0           udp  domain_u    SF         42         42     0
# ...          ...           ...       ...   ...        ...        ...   ...
# 119879         0           tcp      echo  RSTO          0          0     0
# 103694         0           tcp    telnet    S0          0          0     0
# 860            0           tcp      http   REJ          0          0     0
# 15795          0           tcp      http    SF        309       4281     0
# 121958         0           udp  domain_u    SF         43         70     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 35336                0       0    0  ...                   1
# 15594                0       0    0  ...                  20
# 16218                0       0    0  ...                   5
# 109730               0       0    0  ...                   1
# 93900                0       0    0  ...                 244
# ...                ...     ...  ...  ...                 ...
# 119879               0       0    0  ...                   4
# 103694               0       0    0  ...                   4
# 860                  0       0    0  ...                   6
# 15795                0       0    0  ...                 255
# 121958               0       0    0  ...                 254
#
#         dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 35336                     0.00                    1.00
# 15594                     0.08                    0.06
# 16218                     0.03                    0.09
# 109730                    0.00                    1.00
# 93900                     0.96                    0.01
# ...                        ...                     ...
# 119879                    0.02                    0.09
# 103694                    0.02                    0.07
# 860                       0.02                    0.07
# 15795                     1.00                    0.00
# 121958                    1.00                    0.01
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 35336                          0.00                         0.00
# 15594                          0.00                         0.00
# 16218                          0.01                         0.40
# 109730                         0.00                         0.00
# 93900                          0.00                         0.00
# ...                             ...                          ...
# 119879                         0.00                         0.00
# 103694                         0.01                         0.00
# 860                            0.00                         0.00
# 15795                          0.05                         0.05
# 121958                         0.01                         0.00
#
#         dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 35336                   0.10                       0.0                  0.89
# 15594                   1.00                       1.0                  0.00
# 16218                   0.01                       0.0                  0.01
# 109730                  0.08                       0.0                  0.91
# 93900                   0.00                       0.0                  0.00
# ...                      ...                       ...                   ...
# 119879                  0.00                       0.0                  1.00
# 103694                  1.00                       1.0                  0.00
# 860                     0.00                       0.0                  1.00
# 15795                   0.00                       0.0                  0.00
# 121958                  0.00                       0.0                  0.00
#
#         dst_host_srv_rerror_rate    class
# 35336                        1.0  anomaly
# 15594                        0.0  anomaly
# 16218                        0.0   normal
# 109730                       1.0  anomaly
# 93900                        0.0   normal
# ...                          ...      ...
# 119879                       1.0  anomaly
# 103694                       0.0  anomaly
# 860                          1.0  anomaly
# 15795                        0.0   normal
# 121958                       0.0   normal
#
# [127974 rows x 42 columns]

# %%
test_df = test_df.sample(frac=1.0, random_state=42)
test_df
# Out:
#        duration protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 6186          0           tcp     smtp    SF        914        329     0
# 247           0           tcp  private    S0          0          0     0
# 4343          0           tcp     smtp    SF       1012        338     0
# 17527         0           tcp     http    SF        243        667     0
# 13123         0           tcp     http    SF        227        286     0
# ...         ...           ...      ...   ...        ...        ...   ...
# 11964         0           tcp   telnet    S0          0          0     0
# 21575         0           tcp   kshell    S0          0          0     0
# 5390          1           tcp    imap4  RSTO          0         44     0
# 860         282           tcp      ftp    SF        162        599     0
# 15795         6           tcp    other   REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 6186                0       0    0  ...                 155
# 247                 0       0    0  ...                   2
# 4343                0       0    0  ...                 169
# 17527               0       0    0  ...                 255
# 13123               0       0    0  ...                 255
# ...               ...     ...  ...  ...                 ...
# 11964               0       0    0  ...                  86
# 21575               0       0    0  ...                   2
# 5390                0       0    0  ...                  40
# 860                 0       0    2  ...                  57
# 15795               0       0    0  ...                   1
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 6186                     0.61                    0.06
# 247                      0.01                    0.07
# 4343                     0.73                    0.04
# 17527                    1.00                    0.00
# 13123                    1.00                    0.00
# ...                       ...                     ...
# 11964                    0.34                    0.01
# 21575                    0.01                    0.18
# 5390                     0.16                    0.03
# 860                      0.22                    0.03
# 15795                    0.00                    1.00
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 6186                          0.00                         0.00
# 247                           0.00                         0.00
# 4343                          0.01                         0.01
# 17527                         0.00                         0.00
# 13123                         0.00                         0.02
# ...                            ...                          ...
# 11964                         0.00                         0.02
# 21575                         0.00                         0.00
# 5390                          0.00                         0.00
# 860                           0.00                         0.00
# 15795                         0.00                         0.00
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 6186                   0.00                      0.00                  0.01
# 247                    1.00                      1.00                  0.00
# 4343                   0.00                      0.00                  0.00
# 17527                  0.00                      0.00                  0.00
# 13123                  0.00                      0.00                  0.00
# ...                     ...                       ...                   ...
# 11964                  1.00                      1.00                  0.00
# 21575                  1.00                      1.00                  0.00
# 5390                   0.02                      0.08                  0.56
# 860                    0.13                      0.00                  0.02
# 15795                  0.05                      0.00                  0.95
#
#        dst_host_srv_rerror_rate    class
# 6186                       0.01   normal
# 247                        0.00  anomaly
# 4343                       0.00   normal
# 17527                      0.00   normal
# 13123                      0.00   normal
# ...                         ...      ...
# 11964                      0.00  anomaly
# 21575                      0.00  anomaly
# 5390                       0.88  anomaly
# 860                        0.00  anomaly
# 15795                      1.00  anomaly
#
# [22544 rows x 42 columns]

# %% [markdown]
# ### 数据处理

# %%
train_x = train_df.iloc[:, :-1]
test_x = test_df.iloc[:, :-1]
pos_train_x = pos_df.iloc[:, :-1]
col_feature = train_x.dtypes[train_x.dtypes == 'object'].index
num_feature = train_x.dtypes[train_x.dtypes != 'object'].index

def min_max_normalization(data):
    #对原始数据进行min-max归一化处理
        max_val = max(data)
        min_val = min(data)
        if min_val == max_val:
            return data
        else:
            norm_data = [(x - min_val) / (max_val - min_val) for x in data]
            return norm_data
train_num_feature = train_x[num_feature].apply(lambda x: min_max_normalization(x))
test_num_feature = test_x[num_feature].apply(lambda x: min_max_normalization(x))
pos_num_feature = pos_train_x[num_feature].apply(lambda x: min_max_normalization(x))

train_one_hot = pd.get_dummies(train_x[col_feature], dummy_na=True)
pos_one_hot = pd.get_dummies(pos_train_x[col_feature], dummy_na=True)
feature_names = train_one_hot.columns
test_one_hot = pd.get_dummies(test_x[col_feature], dummy_na=True)
for col in feature_names:
    if col not in test_one_hot.columns:
        test_one_hot[col] = 0
# 调整特征的顺序
test_encoded = test_one_hot[feature_names]
train_y = train_df.iloc[:, -1]
test_y = test_df.iloc[:, -1]
pos_train_y = pos_df.iloc[:, -1]

mapping = {'normal':0, 'anomaly':1}
train_y = train_y.map(mapping).T
test_y = test_y.map(mapping).T
pos_train_y = pos_train_y.map(mapping).T

train_x = pd.concat([train_one_hot, train_num_feature], axis=1).values
test_x = pd.concat([test_one_hot, test_num_feature], axis=1).values
pos_train_x = pd.concat([pos_one_hot, pos_num_feature], axis=1).values
train_x = np.array(train_x)
train_y = np.array(train_y).reshape(-1, 1)
test_x = np.array(test_x)
test_y = np.array(test_y).reshape(-1, 1) 
pos_train_x = np.array(pos_train_x)
pos_train_y = np.array(pos_train_y).reshape(-1, 1)

# %%
def auc(y_true, y_pred):
    return np.mean(y_true == y_pred)

# %% [markdown]
# ### DNN模型与训练

# %%
class MLP():
    def __init__(self, input_size, hidden1_size=64, hidden2_size=32, output_size=1):
        self.W1 = np.random.randn(input_size, hidden1_size)
        self.b1 = np.zeros((1, hidden1_size))
        self.W2 = np.random.randn(hidden1_size, hidden2_size)
        self.b2 = np.zeros((1, hidden2_size))
        self.W3 = np.random.randn(hidden2_size, output_size)
        self.b3 = np.zeros((1, output_size))
        self.h1_relu = None
        self.h2_relu = None
        self.eps = 1e-7
        self.pos_weight = 0.5
        
    def forward(self, x):
        h1 = np.dot(x, self.W1) + self.b1
        self.h1_relu = np.maximum(0, h1)
        h2 = np.dot(self.h1_relu, self.W2) + self.b2
        self.h2_relu = np.maximum(0, h2)
        y_pred = np.dot(self.h2_relu, self.W3) + self.b3
        y_pred = 1 / (1 + np.exp(-y_pred))  # 输出用sigmoid激活
        return y_pred 
    
    def BCELoss(self, y_pred, y_true):
        eps = self.eps
        pos_weight = self.pos_weight
        return -((1 - pos_weight) * y_true * np.log(y_pred + eps) + pos_weight * (1 - y_true) * np.log(1 - y_pred + eps)).mean()
    
    def backward(self, x, y, y_pred, lr):
        m = x.shape[0]
        eps = self.eps
        dloss = (y_pred - y) / m
        dW3 = np.dot(self.h2_relu.T, dloss)
        db3 = np.sum(dloss, axis=0, keepdims=True)
        dhidden2 = np.dot(dloss, self.W3.T)
        dhidden2[self.h2_relu <= 0] = 0
        dW2 = np.dot(self.h1_relu.T, dhidden2)
        db2 = np.sum(dhidden2, axis=0, keepdims=True)
        dhidden1 = np.dot(dhidden2, self.W2.T)
        dhidden1[self.h1_relu <= 0] = 0
        dW1 = np.dot(x.T, dhidden1)
        db1 = np.sum(dhidden1, axis=0, keepdims=True)
        self.W3 -= lr * dW3
        self.b3 -= lr * db3
        self.W2 -= lr * dW2
        self.b2 -= lr * db2
        self.W1 -= lr * dW1
        self.b1 -= lr * db1

    def predict(self, x):
        y_pred = self.forward(x)
        return (y_pred > 0.5).astype(int)
    
    def train(self, x, y, test_x, test_y, lr, epochs, batch_size=None):
        m = x.shape[0]
        ll = []
        ll_test = []
        if batch_size is None:
            batch_size = m
        test_loss = self.BCELoss(self.forward(test_x), test_y)
        loss = test_loss
        ll.append(loss)
        ll_test.append(test_loss)
        
        for epoch in range(epochs):
            shuffled_indices = np.random.permutation(m)
            x_shuffled = x[shuffled_indices]
            y_shuffled = y[shuffled_indices]
            for i in range(0, m, batch_size):
                x_batch = x_shuffled[i:i+batch_size]
                y_batch = y_shuffled[i:i+batch_size]
                y_pred = self.forward(x_batch)
                self.backward(x_batch, y_batch, y_pred, lr)
            y_p = self.forward(x)
            loss = self.BCELoss(y_p, y)

            # 在测试集上计算准确率和损失
            test_loss = self.BCELoss(self.forward(test_x), test_y)
            print(f'Epoch {epoch + 1}/{epochs}, loss: {loss:.4f},  test_loss: {test_loss:.4f}')
            ll.append(loss)
            ll_test.append(test_loss)
        return ll, ll_test

# %%
# 创建一个 MLP 实例
mlp = MLP(input_size=train_x.shape[1], hidden1_size=64, hidden2_size=32, output_size=1)

# 训练模型
ll, ll_test = mlp.train(train_x, train_y, test_x, test_y, lr=0.01, epochs=150, batch_size=2048)
# Out:
# Epoch 1/150, loss: 0.3812,  test_loss: 2.0949
# Epoch 2/150, loss: 0.2709,  test_loss: 1.7688
# Epoch 3/150, loss: 0.2367,  test_loss: 1.7026
# Epoch 4/150, loss: 0.2031,  test_loss: 1.7002
# Epoch 5/150, loss: 0.1695,  test_loss: 1.7150
# Epoch 6/150, loss: 0.1427,  test_loss: 1.7368
# Epoch 7/150, loss: 0.1245,  test_loss: 1.7383
# Epoch 8/150, loss: 0.1138,  test_loss: 1.7174
# Epoch 9/150, loss: 0.1063,  test_loss: 1.6669
# Epoch 10/150, loss: 0.1005,  test_loss: 1.6448
# Epoch 11/150, loss: 0.0958,  test_loss: 1.6236
# Epoch 12/150, loss: 0.0920,  test_loss: 1.5988
# Epoch 13/150, loss: 0.0885,  test_loss: 1.5657
# Epoch 14/150, loss: 0.0855,  test_loss: 1.5435
# Epoch 15/150, loss: 0.0828,  test_loss: 1.5191
# Epoch 16/150, loss: 0.0802,  test_loss: 1.4921
# Epoch 17/150, loss: 0.0780,  test_loss: 1.4664
# Epoch 18/150, loss: 0.0761,  test_loss: 1.4410
# Epoch 19/150, loss: 0.0742,  test_loss: 1.4170
# Epoch 20/150, loss: 0.0725,  test_loss: 1.3944
# Epoch 21/150, loss: 0.0708,  test_loss: 1.3776
# Epoch 22/150, loss: 0.0692,  test_loss: 1.3573
# Epoch 23/150, loss: 0.0680,  test_loss: 1.3375
# Epoch 24/150, loss: 0.0663,  test_loss: 1.3247
# Epoch 25/150, loss: 0.0653,  test_loss: 1.3072
# Epoch 26/150, loss: 0.0636,  test_loss: 1.2873
# Epoch 27/150, loss: 0.0623,  test_loss: 1.2727
# Epoch 28/150, loss: 0.0610,  test_loss: 1.2607
# Epoch 29/150, loss: 0.0598,  test_loss: 1.2502
# Epoch 30/150, loss: 0.0585,  test_loss: 1.2420
# Epoch 31/150, loss: 0.0574,  test_loss: 1.2398
# Epoch 32/150, loss: 0.0564,  test_loss: 1.2377
# Epoch 33/150, loss: 0.0555,  test_loss: 1.2353
# Epoch 34/150, loss: 0.0547,  test_loss: 1.2329
# Epoch 35/150, loss: 0.0542,  test_loss: 1.2236
# Epoch 36/150, loss: 0.0532,  test_loss: 1.2282
# Epoch 37/150, loss: 0.0526,  test_loss: 1.2265
# Epoch 38/150, loss: 0.0521,  test_loss: 1.2361
# Epoch 39/150, loss: 0.0515,  test_loss: 1.2268
# Epoch 40/150, loss: 0.0509,  test_loss: 1.2286
# Epoch 41/150, loss: 0.0504,  test_loss: 1.2299
# Epoch 42/150, loss: 0.0500,  test_loss: 1.2267
# Epoch 43/150, loss: 0.0494,  test_loss: 1.2322
# Epoch 44/150, loss: 0.0490,  test_loss: 1.2311
# Epoch 45/150, loss: 0.0485,  test_loss: 1.2419
# Epoch 46/150, loss: 0.0481,  test_loss: 1.2367
# Epoch 47/150, loss: 0.0476,  test_loss: 1.2473
# Epoch 48/150, loss: 0.0472,  test_loss: 1.2496
# Epoch 49/150, loss: 0.0469,  test_loss: 1.2432
# Epoch 50/150, loss: 0.0465,  test_loss: 1.2486
# Epoch 51/150, loss: 0.0462,  test_loss: 1.2482
# Epoch 52/150, loss: 0.0458,  test_loss: 1.2591
# Epoch 53/150, loss: 0.0456,  test_loss: 1.2678
# Epoch 54/150, loss: 0.0453,  test_loss: 1.2500
# Epoch 55/150, loss: 0.0449,  test_loss: 1.2530
# Epoch 56/150, loss: 0.0446,  test_loss: 1.2579
# Epoch 57/150, loss: 0.0442,  test_loss: 1.2650
# Epoch 58/150, loss: 0.0441,  test_loss: 1.2758
# Epoch 59/150, loss: 0.0437,  test_loss: 1.2690
# Epoch 60/150, loss: 0.0435,  test_loss: 1.2677
# Epoch 61/150, loss: 0.0433,  test_loss: 1.2818
# Epoch 62/150, loss: 0.0429,  test_loss: 1.2746
# Epoch 63/150, loss: 0.0427,  test_loss: 1.2718
# Epoch 64/150, loss: 0.0425,  test_loss: 1.2684
# Epoch 65/150, loss: 0.0424,  test_loss: 1.2833
# Epoch 66/150, loss: 0.0421,  test_loss: 1.2711
# Epoch 67/150, loss: 0.0419,  test_loss: 1.2793
# Epoch 68/150, loss: 0.0419,  test_loss: 1.2632
# Epoch 69/150, loss: 0.0415,  test_loss: 1.2883
# Epoch 70/150, loss: 0.0413,  test_loss: 1.2748
# Epoch 71/150, loss: 0.0410,  test_loss: 1.2871
# Epoch 72/150, loss: 0.0406,  test_loss: 1.2843
# Epoch 73/150, loss: 0.0407,  test_loss: 1.2755
# Epoch 74/150, loss: 0.0403,  test_loss: 1.2785
# Epoch 75/150, loss: 0.0400,  test_loss: 1.2843
# Epoch 76/150, loss: 0.0399,  test_loss: 1.2932
# Epoch 77/150, loss: 0.0397,  test_loss: 1.2864
# Epoch 78/150, loss: 0.0396,  test_loss: 1.2975
# Epoch 79/150, loss: 0.0393,  test_loss: 1.2878
# Epoch 80/150, loss: 0.0391,  test_loss: 1.2872
# Epoch 81/150, loss: 0.0391,  test_loss: 1.2985
# Epoch 82/150, loss: 0.0388,  test_loss: 1.2910
# Epoch 83/150, loss: 0.0386,  test_loss: 1.2906
# Epoch 84/150, loss: 0.0385,  test_loss: 1.2925
# Epoch 85/150, loss: 0.0384,  test_loss: 1.2883
# Epoch 86/150, loss: 0.0382,  test_loss: 1.2840
# Epoch 87/150, loss: 0.0381,  test_loss: 1.2906
# Epoch 88/150, loss: 0.0382,  test_loss: 1.2982
# Epoch 89/150, loss: 0.0382,  test_loss: 1.3019
# Epoch 90/150, loss: 0.0379,  test_loss: 1.2973
# Epoch 91/150, loss: 0.0377,  test_loss: 1.2785
# Epoch 92/150, loss: 0.0377,  test_loss: 1.2749
# Epoch 93/150, loss: 0.0375,  test_loss: 1.2769
# Epoch 94/150, loss: 0.0374,  test_loss: 1.2806
# Epoch 95/150, loss: 0.0373,  test_loss: 1.2809
# Epoch 96/150, loss: 0.0371,  test_loss: 1.2844
# Epoch 97/150, loss: 0.0371,  test_loss: 1.2885
# Epoch 98/150, loss: 0.0370,  test_loss: 1.2742
# Epoch 99/150, loss: 0.0369,  test_loss: 1.2810
# Epoch 100/150, loss: 0.0368,  test_loss: 1.2881
# Epoch 101/150, loss: 0.0367,  test_loss: 1.2849
# Epoch 102/150, loss: 0.0366,  test_loss: 1.2822
# Epoch 103/150, loss: 0.0365,  test_loss: 1.2762
# Epoch 104/150, loss: 0.0364,  test_loss: 1.2783
# Epoch 105/150, loss: 0.0363,  test_loss: 1.2771
# Epoch 106/150, loss: 0.0362,  test_loss: 1.2805
# Epoch 107/150, loss: 0.0362,  test_loss: 1.2753
# Epoch 108/150, loss: 0.0361,  test_loss: 1.2751
# Epoch 109/150, loss: 0.0360,  test_loss: 1.2829
# Epoch 110/150, loss: 0.0359,  test_loss: 1.2785
# Epoch 111/150, loss: 0.0359,  test_loss: 1.2707
# Epoch 112/150, loss: 0.0358,  test_loss: 1.2784
# Epoch 113/150, loss: 0.0357,  test_loss: 1.2720
# Epoch 114/150, loss: 0.0356,  test_loss: 1.2739
# Epoch 115/150, loss: 0.0356,  test_loss: 1.2763
# Epoch 116/150, loss: 0.0355,  test_loss: 1.2769
# Epoch 117/150, loss: 0.0354,  test_loss: 1.2754
# Epoch 118/150, loss: 0.0354,  test_loss: 1.2666
# Epoch 119/150, loss: 0.0353,  test_loss: 1.2725
# Epoch 120/150, loss: 0.0353,  test_loss: 1.2612
# Epoch 121/150, loss: 0.0351,  test_loss: 1.2679
# Epoch 122/150, loss: 0.0351,  test_loss: 1.2693
# Epoch 123/150, loss: 0.0350,  test_loss: 1.2712
# Epoch 124/150, loss: 0.0349,  test_loss: 1.2701
# Epoch 125/150, loss: 0.0349,  test_loss: 1.2686
# Epoch 126/150, loss: 0.0350,  test_loss: 1.2783
# Epoch 127/150, loss: 0.0350,  test_loss: 1.2819
# Epoch 128/150, loss: 0.0347,  test_loss: 1.2709
# Epoch 129/150, loss: 0.0346,  test_loss: 1.2630
# Epoch 130/150, loss: 0.0346,  test_loss: 1.2566
# Epoch 131/150, loss: 0.0345,  test_loss: 1.2614
# Epoch 132/150, loss: 0.0344,  test_loss: 1.2605
# Epoch 133/150, loss: 0.0344,  test_loss: 1.2564
# Epoch 134/150, loss: 0.0343,  test_loss: 1.2626
# Epoch 135/150, loss: 0.0343,  test_loss: 1.2635
# Epoch 136/150, loss: 0.0342,  test_loss: 1.2599
# Epoch 137/150, loss: 0.0344,  test_loss: 1.2469
# Epoch 138/150, loss: 0.0342,  test_loss: 1.2463
# Epoch 139/150, loss: 0.0341,  test_loss: 1.2508
# Epoch 140/150, loss: 0.0340,  test_loss: 1.2499
# Epoch 141/150, loss: 0.0339,  test_loss: 1.2541
# Epoch 142/150, loss: 0.0339,  test_loss: 1.2535
# Epoch 143/150, loss: 0.0339,  test_loss: 1.2578
# Epoch 144/150, loss: 0.0338,  test_loss: 1.2515
# Epoch 145/150, loss: 0.0337,  test_loss: 1.2538
# Epoch 146/150, loss: 0.0337,  test_loss: 1.2525
# Epoch 147/150, loss: 0.0337,  test_loss: 1.2566
# Epoch 148/150, loss: 0.0337,  test_loss: 1.2608
# Epoch 149/150, loss: 0.0335,  test_loss: 1.2514
# Epoch 150/150, loss: 0.0335,  test_loss: 1.2453

# %%
plt.plot(ll)
plt.plot(ll_test)

# %%
y_test_pred = mlp.predict(test_x)
test_acc = auc(test_y, y_test_pred)
test_loss = mlp.BCELoss(mlp.forward(test_x), test_y)
print("Test Accuracy: {:.2f}%".format(test_acc * 100))
print(f"Test Loss: {test_loss:.4f}")
# Out:
# Test Accuracy: 75.29%
# Test Loss: 1.2453

# %% [markdown]
# ### 投毒攻击案例

# %%
# 再创建一个 MLP 实例
mlp_poison = MLP(input_size=pos_train_x.shape[1], hidden1_size=64, hidden2_size=32, output_size=1)

# 训练模型
ll_poison, ll_test_poison = mlp_poison.train(pos_train_x, pos_train_y, test_x, test_y, lr=0.01, epochs=125, batch_size=2048)
# Out:
# Epoch 1/125, loss: 0.2831,  test_loss: 4.1221
# Epoch 2/125, loss: 0.2381,  test_loss: 4.0562
# Epoch 3/125, loss: 0.2167,  test_loss: 4.0076
# Epoch 4/125, loss: 0.2042,  test_loss: 3.9423
# Epoch 5/125, loss: 0.1851,  test_loss: 3.8428
# Epoch 6/125, loss: 0.1712,  test_loss: 3.7675
# Epoch 7/125, loss: 0.1589,  test_loss: 3.6902
# Epoch 8/125, loss: 0.1490,  test_loss: 3.6645
# Epoch 9/125, loss: 0.1366,  test_loss: 3.6020
# Epoch 10/125, loss: 0.1292,  test_loss: 3.5888
# Epoch 11/125, loss: 0.1242,  test_loss: 3.5760
# Epoch 12/125, loss: 0.1208,  test_loss: 3.5596
# Epoch 13/125, loss: 0.1170,  test_loss: 3.5624
# Epoch 14/125, loss: 0.1143,  test_loss: 3.5802
# Epoch 15/125, loss: 0.1125,  test_loss: 3.5818
# Epoch 16/125, loss: 0.1100,  test_loss: 3.5736
# Epoch 17/125, loss: 0.1094,  test_loss: 3.5749
# Epoch 18/125, loss: 0.1070,  test_loss: 3.5885
# Epoch 19/125, loss: 0.1056,  test_loss: 3.5971
# Epoch 20/125, loss: 0.1041,  test_loss: 3.6007
# Epoch 21/125, loss: 0.1026,  test_loss: 3.6010
# Epoch 22/125, loss: 0.1014,  test_loss: 3.6139
# Epoch 23/125, loss: 0.1001,  test_loss: 3.6043
# Epoch 24/125, loss: 0.0990,  test_loss: 3.6147
# Epoch 25/125, loss: 0.0977,  test_loss: 3.6091
# Epoch 26/125, loss: 0.0975,  test_loss: 3.6165
# Epoch 27/125, loss: 0.0959,  test_loss: 3.6228
# Epoch 28/125, loss: 0.0949,  test_loss: 3.6299
# Epoch 29/125, loss: 0.0948,  test_loss: 3.6222
# Epoch 30/125, loss: 0.0933,  test_loss: 3.6236
# Epoch 31/125, loss: 0.0925,  test_loss: 3.6274
# Epoch 32/125, loss: 0.0917,  test_loss: 3.6282
# Epoch 33/125, loss: 0.0910,  test_loss: 3.6260
# Epoch 34/125, loss: 0.0901,  test_loss: 3.6332
# Epoch 35/125, loss: 0.0895,  test_loss: 3.6298
# Epoch 36/125, loss: 0.0897,  test_loss: 3.6301
# Epoch 37/125, loss: 0.0902,  test_loss: 3.6335
# Epoch 38/125, loss: 0.0879,  test_loss: 3.6263
# Epoch 39/125, loss: 0.0870,  test_loss: 3.6336
# Epoch 40/125, loss: 0.0871,  test_loss: 3.6286
# Epoch 41/125, loss: 0.0859,  test_loss: 3.6238
# Epoch 42/125, loss: 0.0854,  test_loss: 3.6330
# Epoch 43/125, loss: 0.0849,  test_loss: 3.6318
# Epoch 44/125, loss: 0.0843,  test_loss: 3.6270
# Epoch 45/125, loss: 0.0842,  test_loss: 3.6303
# Epoch 46/125, loss: 0.0833,  test_loss: 3.6295
# Epoch 47/125, loss: 0.0836,  test_loss: 3.6225
# Epoch 48/125, loss: 0.0827,  test_loss: 3.6293
# Epoch 49/125, loss: 0.0823,  test_loss: 3.6245
# Epoch 50/125, loss: 0.0816,  test_loss: 3.6257
# Epoch 51/125, loss: 0.0813,  test_loss: 3.6206
# Epoch 52/125, loss: 0.0810,  test_loss: 3.6203
# Epoch 53/125, loss: 0.0814,  test_loss: 3.6232
# Epoch 54/125, loss: 0.0801,  test_loss: 3.6193
# Epoch 55/125, loss: 0.0796,  test_loss: 3.6203
# Epoch 56/125, loss: 0.0796,  test_loss: 3.6183
# Epoch 57/125, loss: 0.0790,  test_loss: 3.6118
# Epoch 58/125, loss: 0.0789,  test_loss: 3.6157
# Epoch 59/125, loss: 0.0783,  test_loss: 3.6100
# Epoch 60/125, loss: 0.0782,  test_loss: 3.6137
# Epoch 61/125, loss: 0.0777,  test_loss: 3.6136
# Epoch 62/125, loss: 0.0773,  test_loss: 3.6082
# Epoch 63/125, loss: 0.0769,  test_loss: 3.6133
# Epoch 64/125, loss: 0.0766,  test_loss: 3.6088
# Epoch 65/125, loss: 0.0763,  test_loss: 3.5972
# Epoch 66/125, loss: 0.0761,  test_loss: 3.6132
# Epoch 67/125, loss: 0.0762,  test_loss: 3.5984
# Epoch 68/125, loss: 0.0754,  test_loss: 3.5882
# Epoch 69/125, loss: 0.0756,  test_loss: 3.5858
# Epoch 70/125, loss: 0.0757,  test_loss: 3.5939
# Epoch 71/125, loss: 0.0749,  test_loss: 3.5952
# Epoch 72/125, loss: 0.0743,  test_loss: 3.5945
# Epoch 73/125, loss: 0.0744,  test_loss: 3.5836
# Epoch 74/125, loss: 0.0738,  test_loss: 3.5768
# Epoch 75/125, loss: 0.0735,  test_loss: 3.5775
# Epoch 76/125, loss: 0.0735,  test_loss: 3.5639
# Epoch 77/125, loss: 0.0732,  test_loss: 3.5676
# Epoch 78/125, loss: 0.0730,  test_loss: 3.5606
# Epoch 79/125, loss: 0.0730,  test_loss: 3.5479
# Epoch 80/125, loss: 0.0727,  test_loss: 3.5503
# Epoch 81/125, loss: 0.0724,  test_loss: 3.5540
# Epoch 82/125, loss: 0.0721,  test_loss: 3.5507
# Epoch 83/125, loss: 0.0720,  test_loss: 3.5364
# Epoch 84/125, loss: 0.0722,  test_loss: 3.5298
# Epoch 85/125, loss: 0.0716,  test_loss: 3.5231
# Epoch 86/125, loss: 0.0716,  test_loss: 3.5210
# Epoch 87/125, loss: 0.0713,  test_loss: 3.4999
# Epoch 88/125, loss: 0.0713,  test_loss: 3.4972
# Epoch 89/125, loss: 0.0709,  test_loss: 3.5030
# Epoch 90/125, loss: 0.0711,  test_loss: 3.4952
# Epoch 91/125, loss: 0.0707,  test_loss: 3.4786
# Epoch 92/125, loss: 0.0710,  test_loss: 3.4796
# Epoch 93/125, loss: 0.0704,  test_loss: 3.4732
# Epoch 94/125, loss: 0.0704,  test_loss: 3.4570
# Epoch 95/125, loss: 0.0705,  test_loss: 3.4401
# Epoch 96/125, loss: 0.0700,  test_loss: 3.4438
# Epoch 97/125, loss: 0.0698,  test_loss: 3.4356
# Epoch 98/125, loss: 0.0697,  test_loss: 3.4273
# Epoch 99/125, loss: 0.0700,  test_loss: 3.4228
# Epoch 100/125, loss: 0.0695,  test_loss: 3.4246
# Epoch 101/125, loss: 0.0694,  test_loss: 3.4039
# Epoch 102/125, loss: 0.0692,  test_loss: 3.4024
# Epoch 103/125, loss: 0.0692,  test_loss: 3.3899
# Epoch 104/125, loss: 0.0695,  test_loss: 3.3786
# Epoch 105/125, loss: 0.0689,  test_loss: 3.3704
# Epoch 106/125, loss: 0.0690,  test_loss: 3.3690
# Epoch 107/125, loss: 0.0688,  test_loss: 3.3651
# Epoch 108/125, loss: 0.0694,  test_loss: 3.3500
# Epoch 109/125, loss: 0.0684,  test_loss: 3.3395
# Epoch 110/125, loss: 0.0684,  test_loss: 3.3396
# Epoch 111/125, loss: 0.0682,  test_loss: 3.3282
# Epoch 112/125, loss: 0.0685,  test_loss: 3.3262
# Epoch 113/125, loss: 0.0681,  test_loss: 3.3125
# Epoch 114/125, loss: 0.0679,  test_loss: 3.3166
# Epoch 115/125, loss: 0.0691,  test_loss: 3.3081
# Epoch 116/125, loss: 0.0677,  test_loss: 3.3035
# Epoch 117/125, loss: 0.0676,  test_loss: 3.2901
# Epoch 118/125, loss: 0.0676,  test_loss: 3.2829
# Epoch 119/125, loss: 0.0675,  test_loss: 3.2775
# Epoch 120/125, loss: 0.0679,  test_loss: 3.2783
# Epoch 121/125, loss: 0.0676,  test_loss: 3.2570
# Epoch 122/125, loss: 0.0672,  test_loss: 3.2542
# Epoch 123/125, loss: 0.0674,  test_loss: 3.2506
# Epoch 124/125, loss: 0.0670,  test_loss: 3.2428
# Epoch 125/125, loss: 0.0669,  test_loss: 3.2461

# %%
plt.plot(ll_poison)
plt.plot(ll_test_poison)

# %%
y_test_pred_poison = mlp_poison.predict(test_x)
test_acc_poison = auc(test_y, y_test_pred_poison)
test_loss_poison = mlp_poison.BCELoss(mlp_poison.forward(test_x), test_y)
print("Test Accuracy in poison set: {:.2f}%".format(test_acc_poison * 100))
print(f"Test Loss in poison set: {test_loss_poison:.4f}")
# Out:
# Test Accuracy in poison set: 40.29%
# Test Loss in poison set: 3.2461

# %% [markdown]
# ### 保存模型

# %%
import pickle

with open('mlp.pickle', 'wb') as f1:
    pickle.dump(mlp, f1)
with open('mlp_poison.pickle', 'wb') as f2:
    pickle.dump(mlp_poison, f2)

# %% [markdown]
# ### 投毒比例与影响关系研究
